# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv('../data/vgsales.csv')

# %%
name = np.genfromtxt('../data/vgsales_caso_practico.csv', delimiter=',', skip_header=1,
                     usecols=(1), dtype=str)

print(np.unique(name))
# Out:
# ['"3 in 1: Solitaire' '"999: Nine Hours' '"Army Men World War: Land' ...
#  'uDraw Studio: Instant Artist' 'wwe Smackdown vs. Raw 2006'
#  'Â¡Shin Chan Flipa en colores!']

# %%
print(name.ndim)
print(name.shape)
# Out:
# 1
# (16598,)

# %%
print(np.unique(name, return_counts=True))
print(type(np.unique(name, return_counts=True)))
# Out:
# (array(['"3 in 1: Solitaire', '"999: Nine Hours',
#        '"Army Men World War: Land', ..., 'uDraw Studio: Instant Artist',
#        'wwe Smackdown vs. Raw 2006', 'Â¡Shin Chan Flipa en colores!'],
#       dtype='<U132'), array([1, 1, 1, ..., 2, 1, 1], dtype=int64))
# <class 'tuple'>

# %%
uniques, counts = np.unique(name, return_counts=True)
counts
# Out:
# array([1, 1, 1, ..., 2, 1, 1], dtype=int64)

# %%
dict(zip(uniques, counts))
# Out:
# {'"3 in 1: Solitaire': 1,
#  '"999: Nine Hours': 1,
#  '"Army Men World War: Land': 1,
#  '"BCFX: The Black College Football Xperience': 1,
#  '"Barbie: Jet': 2,
#  '"Blast Works: Build': 1,
#  '"Boku no Natsuyasumi 4: Seitouchi Shounen Tanteidan': 1,
#  '"Carnival Games: Monkey See': 1,
#  '"Crouching Tiger': 3,
#  '"Ed': 5,
#  '"Element Girl: Love': 1,
#  '"Flower': 1,
#  '"Go': 2,
#  '"Grand Theft Auto: Mission Pack': 1,
#  '"Hanayaka Kana': 3,
#  '"Hey You': 1,
#  '"Hi! Hamtaro - Little Hamsters': 1,
#  '"Hisshou Pachinko*Pachi-Slot Kouryaku Series DS Vol. 1: Shinseiki Evangelion - Magokoro o': 1,
#  '"Hisshou Pachinko*Pachi-Slot Kouryaku Series DS Vol. 2: Shinseiki Evangelion - Shito': 1,
#  '"Hisshou Pachinko*Pachi-Slot Kouryaku Series Vol. 11: Shinseiki Evangelion - Magokoro o': 1,
#  '"Hisshou Pachinko*Pachi-Slot Kouryaku Series Vol. 12: CR Shinseiki Evangelion - Shito': 1,
#  '"Holy Invasion of Privacy': 1,
#  '"Horrid Henry: The Good': 1,
#  '"Horse Life 4: My Horse': 1,
# ...

# %%
len(name)
# Out:
# 16598

# %%
import collections
collections.Counter(name)
# Out:
# Counter({'Need for Speed: Most Wanted': 12,
#          '"Warhammer 40': 11,
#          'FIFA 14': 9,
#          'Madden NFL 07': 9,
#          'LEGO Marvel Super Heroes': 9,
#          'Ratatouille': 9,
#          'FIFA Soccer 13': 8,
#          'FIFA 15': 8,
#          'LEGO Star Wars II: The Original Trilogy': 8,
#          'Madden NFL 08': 8,
#          'Monopoly': 8,
#          'LEGO Harry Potter: Years 5-7': 8,
#          'The LEGO Movie Videogame': 8,
#          'Cars': 8,
#          'LEGO Jurassic World': 8,
#          'Lego Batman 3: Beyond Gotham': 8,
#          'Terraria': 8,
#          'LEGO The Hobbit': 8,
#          'Angry Birds Star Wars': 8,
#          'FIFA 12': 7,
#          'FIFA Soccer 11': 7,
#          'Madden NFL 06': 7,
#          'LEGO Indiana Jones: The Original Adventures': 7,
#          "Harry Potter and the Sorcerer's Stone": 7,
#          'FIFA Soccer 10': 7,
#          'LEGO Batman: The Videogame': 7,
#          'FIFA Soccer 08': 7,
# ...

# %%
np.sort(dataset[:, 0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Malala Severien\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\Malala Severien\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Malala Severien\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:144, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[45], line 1
# ...
